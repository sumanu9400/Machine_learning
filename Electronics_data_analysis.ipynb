# %% [markdown]
# <a href="https://colab.research.google.com/github/sumanu9400/Machine_learning/blob/main/Electronics_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/product.csv")
display(df)
# Out:
#   Product_ID             Product_Name       Category   Price  Rating  \
# 0       A001       Echo Dot (4th Gen)    Electronics   49.99     4.7
# 1       A002         Fire TV Stick 4K    Electronics   39.99     4.8
# 2       A003   Instant Pot Duo 7-in-1        Kitchen   89.99     4.6
# 3       A004        Apple AirPods Pro    Electronics  249.99     4.8
# 4       A005       Samsung Galaxy S21    Electronics  799.99     4.7
# 5       A006  Dyson V11 Animal Vacuum  Home & Garden  599.99     4.7
# 6       A007       Canon EOS Rebel T7         Camera  549.99     4.5
# 7       A008       LEGO Star Wars Set   Toys & Games  129.99     4.9
# 8       A009  Nintendo Switch Console    Electronics  299.99     4.8
# 9       A010          Fitbit Charge 4    Electronics  129.99     4.6
#
#    Reviews_Count        Brand     Seller_Name  Availability
# 0          23456       Amazon          Amazon      In Stock
# 1          45678       Amazon          Amazon      In Stock
# ...

# %%
df.shape
# Out:
# (10, 9)

# %%
print('my dataframe has {}rows and {} columns'.format(df.shape[0],df.shape[1]))
# Out:
# my dataframe has 10rows and 9 columns

# %%
df.head()
# Out:
#   Product_ID            Product_Name     Category   Price  Rating  \
# 0       A001      Echo Dot (4th Gen)  Electronics   49.99     4.7
# 1       A002        Fire TV Stick 4K  Electronics   39.99     4.8
# 2       A003  Instant Pot Duo 7-in-1      Kitchen   89.99     4.6
# 3       A004       Apple AirPods Pro  Electronics  249.99     4.8
# 4       A005      Samsung Galaxy S21  Electronics  799.99     4.7
#
#    Reviews_Count        Brand    Seller_Name Availability
# 0          23456       Amazon         Amazon     In Stock
# 1          45678       Amazon         Amazon     In Stock
# 2          12345  Instant Pot   AmazonBasics     In Stock
# 3           9876        Apple    Apple Store     In Stock
# 4          14789      Samsung  Samsung Store     In Stock

# %%
df.dtypes
# Out:
# Product_ID        object
# Product_Name      object
# Category          object
# Price            float64
# Rating           float64
# Reviews_Count      int64
# Brand             object
# Seller_Name       object
# Availability      object
# dtype: object

# %%
df.describe()
# Out:
#             Price     Rating  Reviews_Count
# count   10.000000  10.000000      10.000000
# mean   293.990000   4.710000   13529.500000
# std    265.965745   0.119722   12823.272951
# min     39.990000   4.500000    1890.000000
# 25%     99.990000   4.625000    6254.250000
# 50%    189.990000   4.700000    9320.500000
# 75%    487.490000   4.800000   14178.000000
# max    799.990000   4.900000   45678.000000

# %%
df.isnull().sum()
# Out:
# Product_ID       0
# Product_Name     0
# Category         0
# Price            0
# Rating           0
# Reviews_Count    0
# Brand            0
# Seller_Name      0
# Availability     0
# dtype: int64
